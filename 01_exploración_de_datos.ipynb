# %% [markdown]
# Importamos las librerias

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Importamos los datos de Github y los leemos

# %%
# !wget  https://github.com/SebastianVillega5/ProyectoIA/blob/346f5331fe3033a573a605d69c06b5b2c169330d/Machine%20learning%20PQ/Data%20Base/Normal1.zip?raw=true
# !wget https://github.com/SebastianVillega5/ProyectoIA/blob/main/Machine%20learning%20PQ/Data%20Base/sag2.zip?raw=true


! unzip /content/Normal1.zip?raw=true
Ntest=pd.read_csv("Normal1.csv")

! unzip /content/sag2.zip?raw=true
Stest=pd.read_csv("sag2.csv")
# Out:
# --2023-05-22 22:48:48--  https://github.com/SebastianVillega5/ProyectoIA/blob/346f5331fe3033a573a605d69c06b5b2c169330d/Machine%20learning%20PQ/Data%20Base/Normal1.zip?raw=true
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SebastianVillega5/ProyectoIA/raw/346f5331fe3033a573a605d69c06b5b2c169330d/Machine%20learning%20PQ/Data%20Base/Normal1.zip [following]
# --2023-05-22 22:48:48--  https://github.com/SebastianVillega5/ProyectoIA/raw/346f5331fe3033a573a605d69c06b5b2c169330d/Machine%20learning%20PQ/Data%20Base/Normal1.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SebastianVillega5/ProyectoIA/346f5331fe3033a573a605d69c06b5b2c169330d/Machine%20learning%20PQ/Data%20Base/Normal1.zip [following]
# --2023-05-22 22:48:48--  https://raw.githubusercontent.com/SebastianVillega5/ProyectoIA/346f5331fe3033a573a605d69c06b5b2c169330d/Machine%20learning%20PQ/Data%20Base/Normal1.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584857 (571K) [application/zip]
# Saving to: ‘Normal1.zip?raw=true.1’
#
# Normal1.zip?raw=tru 100%[===================>] 571.15K  --.-KB/s    in 0.05s
#
# 2023-05-22 22:48:48 (12.4 MB/s) - ‘Normal1.zip?raw=true.1’ saved [584857/584857]
#
# --2023-05-22 22:48:48--  https://github.com/SebastianVillega5/ProyectoIA/blob/main/Machine%20learning%20PQ/Data%20Base/sag2.zip?raw=true
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SebastianVillega5/ProyectoIA/raw/main/Machine%20learning%20PQ/Data%20Base/sag2.zip [following]
# --2023-05-22 22:48:48--  https://github.com/SebastianVillega5/ProyectoIA/raw/main/Machine%20learning%20PQ/Data%20Base/sag2.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SebastianVillega5/ProyectoIA/main/Machine%20learning%20PQ/Data%20Base/sag2.zip [following]
# --2023-05-22 22:48:48--  https://raw.githubusercontent.com/SebastianVillega5/ProyectoIA/main/Machine%20learning%20PQ/Data%20Base/sag2.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17170993 (16M) [application/zip]
# Saving to: ‘sag2.zip?raw=true.1’
#
# sag2.zip?raw=true.1 100%[===================>]  16.38M  72.2MB/s    in 0.2s
#
# 2023-05-22 22:48:49 (72.2 MB/s) - ‘sag2.zip?raw=true.1’ saved [17170993/17170993]
#
# Archive:  /content/Normal1.zip?raw=true
# replace Normal1.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Normal1.csv
# Archive:  /content/sag2.zip?raw=true
#   inflating: sag2.csv

# %%
print("La forma de los datos Normal1 y sag son respectivamente:")
print(np.shape(Ntest),np.shape(Stest))
# Out:
# La forma de los datos Normal1 y sag son respectivamente:
# (533, 20001) (533, 10001)

# %% [markdown]
# Grafiquemos algunos de los datos:

# %%
nNtest=np.array(Ntest)
print(np.shape(nNtest[:,1]))

  
plt.plot(nNtest[:,1])
plt.title("Onda sana")
plt.xlabel("Tiempo")
plt.ylabel("A")
# Out:
# (533,)
# Text(0, 0.5, 'A')

# %% [markdown]
# Ahora con la perturbacion:

# %%
nStest=np.array(Stest)
print(np.shape(nStest[:,1]))

  
plt.plot(nStest[:,1],label='sag1')
plt.plot(nStest[:,2],label='sag2')
plt.plot(nStest[:,3],label='sag3')
plt.title("Ondas con perturbacion")
plt.legend()
plt.xlabel("Tiempo")
plt.ylabel("A")
# Out:
# (533,)
# Text(0, 0.5, 'A')
